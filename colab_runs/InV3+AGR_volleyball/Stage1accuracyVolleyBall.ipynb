# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# !pip install "numpy<1.24"
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 17.1/17.1 MB 51.6 MB/s eta 0:00:00
# ...
#   Attempting uninstall: numpy
#     Found existing installation: numpy 1.25.2
#     Uninstalling numpy-1.25.2:
#       Successfully uninstalled numpy-1.25.2
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# chex 0.1.85 requires numpy>=1.24.1, but you have numpy 1.23.5 which is incompatible.
# ...

# %%
# !git clone https://github.com/rjn991/8thsemproject
# Out:
# Cloning into '8thsemproject'...
# remote: Enumerating objects: 128, done.
# remote: Counting objects: 100% (128/128), done.
# remote: Compressing objects: 100% (111/111), done.
# remote: Total 128 (delta 16), reused 119 (delta 10), pack-reused 0
# Receiving objects: 100% (128/128), 20.02 MiB | 18.90 MiB/s, done.
# Resolving deltas: 100% (16/16), done.

# %%
# %cd 8thsemproject
# Out:
# /content/8thsemproject

# %%
# !ls
# Out:
# 8thsemproject  drive  sample_data

# %%
! mkdir ~/.kaggle
! cp kaggle.json ~/.kaggle/
! chmod 600 ~/.kaggle/kaggle.json

# %%
! kaggle datasets download -d rjn992/rjn991voll
# Out:
# ...
# 100% 57.8G/57.9G [12:27<00:00, 136MB/s]
# 100% 57.9G/57.9G [12:27<00:00, 83.1MB/s]

# %%
# !mkdir -p data/volleyball

# %%
# !unzip /content/rjn991voll.zip -d data/volleyball
# Out:
# Streaming output truncated to the last 5000 lines.
#   inflating: data/volleyball/videos/8/44340/44326.jpg
#   inflating: data/volleyball/videos/8/44340/44327.jpg
#   inflating: data/volleyball/videos/8/44340/44328.jpg
#   inflating: data/volleyball/videos/8/44340/44329.jpg
#   inflating: data/volleyball/videos/8/44340/44330.jpg
#   inflating: data/volleyball/videos/8/44340/44331.jpg
#   inflating: data/volleyball/videos/8/44340/44332.jpg
#   inflating: data/volleyball/videos/8/44340/44333.jpg
#   inflating: data/volleyball/videos/8/44340/44334.jpg
#   inflating: data/volleyball/videos/8/44340/44335.jpg
#   inflating: data/volleyball/videos/8/44340/44336.jpg
#   inflating: data/volleyball/videos/8/44340/44337.jpg
#   inflating: data/volleyball/videos/8/44340/44338.jpg
#   inflating: data/volleyball/videos/8/44340/44339.jpg
#   inflating: data/volleyball/videos/8/44340/44340.jpg
#   inflating: data/volleyball/videos/8/44340/44341.jpg
# ...

# %%
# !mv data/volleyball/videos/* data/volleyball

# %%
# !git clone https://github.com/longcw/RoIAlign.pytorch
# Out:
# Cloning into 'RoIAlign.pytorch'...
# remote: Enumerating objects: 197, done.
# remote: Total 197 (delta 0), reused 0 (delta 0), pack-reused 197
# Receiving objects: 100% (197/197), 659.58 KiB | 17.83 MiB/s, done.
# Resolving deltas: 100% (97/97), done.

# %%
# !cd RoIAlign.pytorch/ && python setup.py install && ./test.sh
# Out:
# running install
# /usr/local/lib/python3.10/dist-packages/setuptools/_distutils/cmd.py:66: SetuptoolsDeprecationWarning: setup.py install is deprecated.
# !!
#
#         ********************************************************************************
#         Please avoid running ``setup.py`` directly.
#         Instead, use pypa/build, pypa/installer, pypa/build or
#         other standards-based tools.
#
#         See https://blog.ganssle.io/articles/2021/10/setup-py-deprecated.html for details.
#         ********************************************************************************
#
# !!
#   self.initialize_options()
# /usr/local/lib/python3.10/dist-packages/setuptools/_distutils/cmd.py:66: EasyInstallDeprecationWarning: easy_install command is deprecated.
# !!
#
#         ********************************************************************************
#         Please avoid running ``setup.py`` and ``easy_install``.
# ...

# %%
# !python scripts/train_volleyball_stage1.py
# Out:
# =====================Config=====================
# image_size :  (720, 1280)
# batch_size :  8
# test_batch_size :  4
# num_boxes :  12
# use_gpu :  True
# use_multi_gpu :  True
# device_list :  0,1,2,3
# dataset_name :  volleyball
# data_path :  data/volleyball
# train_seqs :  [1, 3, 6, 7, 10, 13, 15, 16, 18, 22, 23, 31, 32, 36, 38, 39, 40, 41, 42, 48, 50, 52, 53, 54, 0, 2, 8, 12, 17, 19, 24, 26, 27, 28, 30, 33, 46, 49, 51]
# test_seqs :  [4, 5, 9, 11, 14, 20, 21, 25, 29, 34, 35, 37, 43, 44, 45, 47]
# backbone :  inv3
# crop_size :  (5, 5)
# train_backbone :  True
# out_size :  (87, 157)
# emb_features :  1056
# num_actions :  9
# num_activities :  8
# actions_loss_weight :  1.0
# actions_weights :  [1.0, 1.0, 2.0, 3.0, 1.0, 2.0, 2.0, 0.2, 1.0]
# num_frames :  1
# num_before :  5
# num_after :  4
# num_features_boxes :  1024
# num_features_relation :  256
# num_graph :  16
# num_features_gcn :  1024
# gcn_layers :  1
# tau_sqrt :  False
# pos_threshold :  0.2
# ...

# %%
# !cp "/content/8thsemproject/result/[Collective_stage1_stage1]<2024-03-13_14-19-00>/stage1_epoch32_86.64%.pth" /content/drive/MyDrive/models
